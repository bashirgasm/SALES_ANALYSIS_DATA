# %% [markdown]
# <a href="https://colab.research.google.com/github/bashirgasm/SALES_ANALYSIS_DATA/blob/main/SalesDataAnalysis.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
'''
Q1. What is the overall sales trend?
Q2. Which are the Top 10 products by sales?
Q3. Which are the Most Selling Products?
Q4. Which is the most preferred Ship Mode?
Q5. Which are the Most Profitable Category and Sub-Category?

'''
# Out:
# '\nQ1. What is the overall sales trend?\nQ2. Which are the Top 10 products by sales?\nQ3. Which are the Most Selling Products?\nQ4. Which is the most preferred Ship Mode?\nQ5. Which are the Most Profitable Category and Sub-Category?\n\n'

# %%
from ast import increment_lineno
# Importing Libaries
# Data Manipulation
import pandas as pd
# Data Visualization
import matplotlib.pyplot as plt
# %matplotlib inline
import seaborn as sns

# %%
# Importing Dataset
import os
import io
file_path="/superstore_sales.xlsx"
#file_path = "E:/CONFERNCE/superstore_sales.xlsx"
df = pd.read_excel(file_path).head(5)

#df = pd.read_excel(io.StringIO(uploaded['superstore_sales.xlsx'].decode('utf-8'))).head(5)
#df
# Out:
# ---------------------------------------------------------------------------
# FileNotFoundError                         Traceback (most recent call last)
# <ipython-input-28-1a3fdfa699f5> in <cell line: 6>()
#       4 file_path="/superstore_sales.xlsx"
#       5 #file_path = "E:/CONFERNCE/superstore_sales.xlsx"
# ----> 6 df = pd.read_excel(file_path).head(5)
#       7
#       8 #df = pd.read_excel(io.StringIO(uploaded['superstore_sales.xlsx'].decode('utf-8'))).head(5)
#
# /usr/local/lib/python3.10/dist-packages/pandas/io/excel/_base.py in read_excel(io, sheet_name, header, names, index_col, usecols, dtype, engine, converters, true_values, false_values, skiprows, nrows, na_values, keep_default_na, na_filter, verbose, parse_dates, date_parser, date_format, thousands, decimal, comment, skipfooter, storage_options, dtype_backend)
#     476     if not isinstance(io, ExcelFile):
#     477         should_close = True
# ...

# %%
# Data Audit
df.head(5)
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-20-c1357da64543> in <cell line: 2>()
#       1 # Data Audit
# ----> 2 df.head(5)
#
# NameError: name 'df' is not defined

# %%
# Last five rows of dataset
sd.tail(5)

# %%
# Shape of Dataset
sd.shape

# %%
# Get the columns in Dataset
sd.columns

# %%
# Get a consise summary of Dataset
sd.info()

# %%
# Checking missing valyes in your Dataset
sd.isnull().sum()

# %%
# Getting Descriptive statistics summary of Dataset
sd.describe()

# %%
# Exploratory Data Analysis
# What is overall Sales Trend
sd.order_date.min()

# %%
sd.order_date.max()

# %%
# Getting Monthly year from Dataset
sd['month_year']=sd['order_date'].apply(lambda x:x.strftime('%y-%m'))

# %%
sd['month_year']

# %%
sd.groupby('month_year').count()

# %%
sd.groupby('month_year').sum()
